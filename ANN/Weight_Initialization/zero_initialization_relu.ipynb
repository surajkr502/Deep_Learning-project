# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ushape.csv',header=None)

# %%
df.head()
# Out:
#           0         1    2
# 0  0.031595  0.986988  0.0
# 1  2.115098 -0.046244  1.0
# 2  0.882490 -0.075756  0.0
# 3 -0.055144 -0.037332  1.0
# 4  0.829545 -0.539321  1.0

# %%
df.columns = ['X', 'Y', 'class']

# %%
# plt.scatter(df['X'],df['Y'],c=df['class'])

plt.scatter(
    df['X'],
    df['Y'],
    c=df['class']
)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('U-Shape Dataset')
plt.show()

# %%
X = df.iloc[:,0:2].values
y = df.iloc[:,-1].values

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(2,activation='sigmoid',input_dim=2))
model.add(Dense(1,activation='sigmoid'))

model.summary()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                      │ (None, 2)                   │               6 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               3 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Set parameters to 0
model.get_weights()
# Out:
# [array([[ 0.4053229,  0.6475558],
#         [-0.5666029,  0.350708 ]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[-0.2568884 ],
#         [ 0.49274385]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
initial_weights = model.get_weights()

# %%
initial_weights[0] = np.ones(model.get_weights()[0].shape)*0.5
initial_weights[1] = np.ones(model.get_weights()[1].shape)*0.5
initial_weights[2] = np.ones(model.get_weights()[2].shape)*0.5
initial_weights[3] = np.ones(model.get_weights()[3].shape)*0.5

# %%
model.set_weights(initial_weights)

# %%
model.get_weights()
# Out:
# [array([[0.5, 0.5],
#         [0.5, 0.5]], dtype=float32),
#  array([0.5, 0.5], dtype=float32),
#  array([[0.5],
#         [0.5]], dtype=float32),
#  array([0.5], dtype=float32)]

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history = model.fit(X,y,epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 0.5000 - loss: 0.8636 - val_accuracy: 0.5000 - val_loss: 0.8362
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5000 - loss: 0.8613 - val_accuracy: 0.5000 - val_loss: 0.8342
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5000 - loss: 0.8591 - val_accuracy: 0.5000 - val_loss: 0.8322
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5000 - loss: 0.8572 - val_accuracy: 0.5000 - val_loss: 0.8302
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5000 - loss: 0.8550 - val_accuracy: 0.5000 - val_loss: 0.8281
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5000 - loss: 0.8529 - val_accuracy: 0.5000 - val_loss: 0.8261
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5000 - loss: 0.8507 - val_accuracy: 0.5000 - val_loss: 0.8241
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5000 - loss: 0.8487 - val_accuracy: 0.5000 - val_loss: 0.8221
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5000 - loss: 0.8466 - val_accuracy: 0.5000 - val_loss: 0.8201
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.5000 - loss: 0.8445 - val_accuracy: 0.5000 - val_loss: 0.8182
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5000 - loss: 0.8426 - val_accuracy: 0.5000 - val_loss: 0.8163
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5000 - loss: 0.8404 - val_accuracy: 0.5000 - val_loss: 0.8144
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5000 - loss: 0.8384 - val_accuracy: 0.5000 - val_loss: 0.8126
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5000 - loss: 0.8366 - val_accuracy: 0.5000 - val_loss: 0.8107
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5000 - loss: 0.8347 - val_accuracy: 0.5000 - val_loss: 0.8089
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5000 - loss: 0.8328 - val_accuracy: 0.5000 - val_loss: 0.8071
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5000 - loss: 0.8307 - val_accuracy: 0.5000 - val_loss: 0.8054
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5000 - loss: 0.8290 - val_accuracy: 0.5000 - val_loss: 0.8036
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5000 - loss: 0.8272 - val_accuracy: 0.5000 - val_loss: 0.8018
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5000 - loss: 0.8253 - val_accuracy: 0.5000 - val_loss: 0.8001
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5000 - loss: 0.8233 - val_accuracy: 0.5000 - val_loss: 0.7984
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5000 - loss: 0.8215 - val_accuracy: 0.5000 - val_loss: 0.7966
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5000 - loss: 0.8195 - val_accuracy: 0.5000 - val_loss: 0.7949
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5000 - loss: 0.8179 - val_accuracy: 0.5000 - val_loss: 0.7931
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5000 - loss: 0.8160 - val_accuracy: 0.5000 - val_loss: 0.7914
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5000 - loss: 0.8141 - val_accuracy: 0.5000 - val_loss: 0.7898
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5000 - loss: 0.8125 - val_accuracy: 0.5000 - val_loss: 0.7882
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5000 - loss: 0.8107 - val_accuracy: 0.5000 - val_loss: 0.7866
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5000 - loss: 0.8091 - val_accuracy: 0.5000 - val_loss: 0.7850
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5000 - loss: 0.8073 - val_accuracy: 0.5000 - val_loss: 0.7836
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5000 - loss: 0.8059 - val_accuracy: 0.5000 - val_loss: 0.7821
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5000 - loss: 0.8042 - val_accuracy: 0.5000 - val_loss: 0.7807
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5000 - loss: 0.8030 - val_accuracy: 0.5000 - val_loss: 0.7792
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5000 - loss: 0.8011 - val_accuracy: 0.5000 - val_loss: 0.7777
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5000 - loss: 0.7996 - val_accuracy: 0.5000 - val_loss: 0.7763
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5000 - loss: 0.7980 - val_accuracy: 0.5000 - val_loss: 0.7749
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5000 - loss: 0.7966 - val_accuracy: 0.5000 - val_loss: 0.7734
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5000 - loss: 0.7951 - val_accuracy: 0.5000 - val_loss: 0.7720
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5000 - loss: 0.7934 - val_accuracy: 0.5000 - val_loss: 0.7706
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5000 - loss: 0.7919 - val_accuracy: 0.5000 - val_loss: 0.7692
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5000 - loss: 0.7905 - val_accuracy: 0.5000 - val_loss: 0.7678
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5000 - loss: 0.7889 - val_accuracy: 0.5000 - val_loss: 0.7664
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5000 - loss: 0.7874 - val_accuracy: 0.5000 - val_loss: 0.7650
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5000 - loss: 0.7859 - val_accuracy: 0.5000 - val_loss: 0.7637
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5000 - loss: 0.7844 - val_accuracy: 0.5000 - val_loss: 0.7623
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5000 - loss: 0.7832 - val_accuracy: 0.5000 - val_loss: 0.7610
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5000 - loss: 0.7814 - val_accuracy: 0.5000 - val_loss: 0.7597
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5000 - loss: 0.7802 - val_accuracy: 0.5000 - val_loss: 0.7584
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5000 - loss: 0.7790 - val_accuracy: 0.5000 - val_loss: 0.7572
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5000 - loss: 0.7774 - val_accuracy: 0.5000 - val_loss: 0.7560
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5000 - loss: 0.7763 - val_accuracy: 0.5000 - val_loss: 0.7548
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5000 - loss: 0.7748 - val_accuracy: 0.5000 - val_loss: 0.7537
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5000 - loss: 0.7737 - val_accuracy: 0.5000 - val_loss: 0.7525
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5000 - loss: 0.7723 - val_accuracy: 0.5000 - val_loss: 0.7513
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5000 - loss: 0.7710 - val_accuracy: 0.5000 - val_loss: 0.7502
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5000 - loss: 0.7697 - val_accuracy: 0.5000 - val_loss: 0.7490
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5000 - loss: 0.7687 - val_accuracy: 0.5000 - val_loss: 0.7479
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5000 - loss: 0.7673 - val_accuracy: 0.5000 - val_loss: 0.7468
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5000 - loss: 0.7661 - val_accuracy: 0.5000 - val_loss: 0.7457
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5000 - loss: 0.7648 - val_accuracy: 0.5000 - val_loss: 0.7446
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5000 - loss: 0.7637 - val_accuracy: 0.5000 - val_loss: 0.7436
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5000 - loss: 0.7625 - val_accuracy: 0.5000 - val_loss: 0.7425
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5000 - loss: 0.7614 - val_accuracy: 0.5000 - val_loss: 0.7415
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5000 - loss: 0.7602 - val_accuracy: 0.5000 - val_loss: 0.7405
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5000 - loss: 0.7592 - val_accuracy: 0.5000 - val_loss: 0.7395
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5000 - loss: 0.7581 - val_accuracy: 0.5000 - val_loss: 0.7385
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5000 - loss: 0.7571 - val_accuracy: 0.5000 - val_loss: 0.7376
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5000 - loss: 0.7560 - val_accuracy: 0.5000 - val_loss: 0.7367
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5000 - loss: 0.7550 - val_accuracy: 0.5000 - val_loss: 0.7357
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5000 - loss: 0.7539 - val_accuracy: 0.5000 - val_loss: 0.7348
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5000 - loss: 0.7530 - val_accuracy: 0.5000 - val_loss: 0.7339
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5000 - loss: 0.7519 - val_accuracy: 0.5000 - val_loss: 0.7330
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5000 - loss: 0.7509 - val_accuracy: 0.5000 - val_loss: 0.7321
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5000 - loss: 0.7499 - val_accuracy: 0.5000 - val_loss: 0.7312
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5000 - loss: 0.7489 - val_accuracy: 0.5000 - val_loss: 0.7304
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5000 - loss: 0.7480 - val_accuracy: 0.5000 - val_loss: 0.7295
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5000 - loss: 0.7472 - val_accuracy: 0.5000 - val_loss: 0.7286
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5000 - loss: 0.7461 - val_accuracy: 0.5000 - val_loss: 0.7278
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5000 - loss: 0.7451 - val_accuracy: 0.5000 - val_loss: 0.7270
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5000 - loss: 0.7443 - val_accuracy: 0.5000 - val_loss: 0.7262
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5000 - loss: 0.7434 - val_accuracy: 0.5000 - val_loss: 0.7254
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5000 - loss: 0.7426 - val_accuracy: 0.5000 - val_loss: 0.7246
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5000 - loss: 0.7418 - val_accuracy: 0.5000 - val_loss: 0.7239
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5000 - loss: 0.7409 - val_accuracy: 0.5000 - val_loss: 0.7231
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5000 - loss: 0.7400 - val_accuracy: 0.5000 - val_loss: 0.7225
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5000 - loss: 0.7394 - val_accuracy: 0.5000 - val_loss: 0.7218
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5000 - loss: 0.7385 - val_accuracy: 0.5000 - val_loss: 0.7212
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5000 - loss: 0.7380 - val_accuracy: 0.5000 - val_loss: 0.7205
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5000 - loss: 0.7371 - val_accuracy: 0.5000 - val_loss: 0.7198
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5000 - loss: 0.7364 - val_accuracy: 0.5000 - val_loss: 0.7192
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5000 - loss: 0.7357 - val_accuracy: 0.5000 - val_loss: 0.7185
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5000 - loss: 0.7349 - val_accuracy: 0.5000 - val_loss: 0.7179
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5000 - loss: 0.7342 - val_accuracy: 0.5000 - val_loss: 0.7173
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5000 - loss: 0.7336 - val_accuracy: 0.5000 - val_loss: 0.7166
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5000 - loss: 0.7329 - val_accuracy: 0.5000 - val_loss: 0.7160
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5000 - loss: 0.7321 - val_accuracy: 0.5000 - val_loss: 0.7155
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5000 - loss: 0.7315 - val_accuracy: 0.5000 - val_loss: 0.7149
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5000 - loss: 0.7309 - val_accuracy: 0.5000 - val_loss: 0.7143
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5000 - loss: 0.7303 - val_accuracy: 0.5000 - val_loss: 0.7138
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5000 - loss: 0.7296 - val_accuracy: 0.5000 - val_loss: 0.7132

# %%
model.get_weights()
# Out:
# [array([[0.7009089 , 0.7009089 ],
#         [0.24357283, 0.24357283]], dtype=float32),
#  array([0.27542603, 0.27542603], dtype=float32),
#  array([[0.26858667],
#         [0.26858667]], dtype=float32),
#  array([0.25437185], dtype=float32)]

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X,y.astype('int'), clf=model, legend=2)
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 from mlxtend.plotting import plot_decision_regions
# ----> 2 plot_decision_regions(X,y.astype('int'), clf=model, legend=2)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mlxtend\plotting\decision_regions.py:306, in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#     300 contourf_kwargs_default = {"alpha": 0.45, "antialiased": True}
#     301 contourf_kwargs = format_kwarg_dictionaries(
#     302     default_kwargs=contourf_kwargs_default,
#     303     user_kwargs=contourf_kwargs,
#     304     protected_keys=["colors", "levels"],
#     305 )
# --> 306 cset = ax.contourf(
#     307     xx,
#     308     yy,
#     309     Z_indexed,
#     310     colors=colors,
#     311     levels=np.arange(Z.max() + 2) - 0.5,
#     312     **contourf_kwargs,
#     313 )
#     315 contour_kwargs_default = {"linewidths": 0.5, "colors": "k", "antialiased": True}
#     316 contour_kwargs = format_kwarg_dictionaries(
#     317     default_kwargs=contour_kwargs_default,
#     318     user_kwargs=contour_kwargs,
#     319     protected_keys=[],
#     320 )
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\axes\_axes.py:7167, in Axes.contourf(self, *args, **kwargs)
#    7156 """
#    7157 Plot filled contours.
#    7158
#    (...)
#    7164 %(contour_doc)s
#    7165 """
#    7166 kwargs['filled'] = True
# -> 7167 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    7168 self._request_autoscale_view()
#    7169 return contours
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\contour.py:729, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, colorizer, extend, antialiased, nchunk, locator, transform, negative_linestyles, *args, **kwargs)
#     725 self._orig_linestyles = linestyles  # Only kept for user access.
#     726 self.negative_linestyles = mpl._val_or_rc(negative_linestyles,
#     727                                           'contour.negative_linestyle')
# --> 729 kwargs = self._process_args(*args, **kwargs)
#     730 self._process_levels()
#     732 self._extend_min = self.extend in ['min', 'both']
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\contour.py:1348, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1345         corner_mask = mpl.rcParams['contour.corner_mask']
#    1346 self._corner_mask = corner_mask
# -> 1348 x, y, z = self._contour_args(args, kwargs)
#    1350 contour_generator = contourpy.contour_generator(
#    1351     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1352     line_type=contourpy.LineType.SeparateCode,
#    1353     fill_type=contourpy.FillType.OuterCode,
#    1354     chunk_size=self.nchunk)
#    1356 t = self.get_transform()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\contour.py:1392, in QuadContourSet._contour_args(self, args, kwargs)
#    1390 else:
#    1391     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
# -> 1392 z = ma.masked_invalid(z, copy=False)
#    1393 self.zmax = z.max().astype(float)
#    1394 self.zmin = z.min().astype(float)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\numpy\ma\core.py:2429, in masked_invalid(a, copy)
#    2401 """
#    2402 Mask an array where invalid values occur (NaNs or infs).
#    2403
#    (...)
#    2426
#    2427 """
#    2428 a = np.array(a, copy=None, subok=True)
# -> 2429 res = masked_where(~(np.isfinite(a)), a, copy=copy)
#    2430 # masked_invalid previously never returned nomask as a mask and doing so
#    2431 # threw off matplotlib (gh-22842).  So use shrink=False:
#    2432 if res._mask is nomask:
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
