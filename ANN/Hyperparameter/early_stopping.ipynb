# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pylab import rcParams
import matplotlib.pyplot as plt
import warnings
from mlxtend.plotting import plot_decision_regions
from matplotlib.colors import ListedColormap
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\sawsu\AppData\Roaming\Python\Python313\site-packages\pandas\core\computation\expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
X, y = make_circles(n_samples=100, noise=0.1, random_state=1)

# %%
sns.scatterplot(x=X[:,0],y=X[:,1],hue=y)
# Out:
# <Axes: >

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3500, verbose=0)

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
print(X_test.dtype)
print(y_test.dtype)
# Out:
# float64
# int64

# %%
pred = model.predict(X_test[:5])
print(pred)
print(pred.shape)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# [[4.3316418e-01]
#  [1.9666398e-02]
#  [9.7966307e-01]
#  [8.2550764e-01]
#  [3.5354661e-04]]
# (5, 1)

# %%
class KerasWrapper:
    def __init__(self, model):
        self.model = model

    def predict(self, X):
        return (self.model.predict(X, verbose=0) > 0.5).astype(int).ravel()

# %%
print(type(model))
# Out:
# <class 'keras.src.models.sequential.Sequential'>

# %%
wrapped_model = KerasWrapper(model)

plot_decision_regions(
    X_test,
    y_test.ravel(),
    clf=wrapped_model,
    legend=2
)

plt.show()

# %% [markdown]
# # Early Stopping

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
callback = EarlyStopping(
    monitor="val_loss",
    min_delta=0.00001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False
)

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3500, callbacks=callback)
# Out:
# Epoch 1/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.5375 - loss: 0.6909 - val_accuracy: 0.4500 - val_loss: 0.6957
# Epoch 2/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5375 - loss: 0.6895 - val_accuracy: 0.4500 - val_loss: 0.6987
# Epoch 3/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5750 - loss: 0.6876 - val_accuracy: 0.4500 - val_loss: 0.6998
# Epoch 4/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5625 - loss: 0.6871 - val_accuracy: 0.4500 - val_loss: 0.7002
# Epoch 5/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5500 - loss: 0.6856 - val_accuracy: 0.4500 - val_loss: 0.7015
# Epoch 6/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5625 - loss: 0.6846 - val_accuracy: 0.4000 - val_loss: 0.7033
# Epoch 7/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5500 - loss: 0.6844 - val_accuracy: 0.3500 - val_loss: 0.7057
# Epoch 8/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5750 - loss: 0.6828 - val_accuracy: 0.3500 - val_loss: 0.7075
# Epoch 9/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5625 - loss: 0.6827 - val_accuracy: 0.3500 - val_loss: 0.7099
# Epoch 10/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5625 - loss: 0.6818 - val_accuracy: 0.3500 - val_loss: 0.7113
# Epoch 11/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5625 - loss: 0.6808 - val_accuracy: 0.3500 - val_loss: 0.7119
# Epoch 12/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5625 - loss: 0.6805 - val_accuracy: 0.3500 - val_loss: 0.7122
# Epoch 13/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5625 - loss: 0.6796 - val_accuracy: 0.4000 - val_loss: 0.7128
# Epoch 14/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5625 - loss: 0.6791 - val_accuracy: 0.4000 - val_loss: 0.7130
# Epoch 15/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5625 - loss: 0.6784 - val_accuracy: 0.4000 - val_loss: 0.7136
# Epoch 16/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5625 - loss: 0.6779 - val_accuracy: 0.3500 - val_loss: 0.7143
# Epoch 17/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5625 - loss: 0.6776 - val_accuracy: 0.3500 - val_loss: 0.7146
# Epoch 18/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5750 - loss: 0.6768 - val_accuracy: 0.3500 - val_loss: 0.7149
# Epoch 19/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5750 - loss: 0.6762 - val_accuracy: 0.3500 - val_loss: 0.7143
# Epoch 20/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5750 - loss: 0.6758 - val_accuracy: 0.3500 - val_loss: 0.7147
# Epoch 21/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5625 - loss: 0.6755 - val_accuracy: 0.3500 - val_loss: 0.7150
# Epoch 21: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
class KerasWrapper:
    def __init__(self, model):
        self.model = model

    def predict(self, X):
        return (self.model.predict(X, verbose=0) > 0.5).astype(int).ravel()

# %%
wrapped_model = KerasWrapper(model)

plot_decision_regions(
    X_test,
    y_test.ravel(),
    clf=wrapped_model,
    legend=2
)

plt.show()
