# %%
from zipfile import ZipFile
with ZipFile('archive (1).zip') as zip_ref: 
    zip_ref.extractall('datasets')
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 from zipfile import ZipFile
# ----> 2 with ZipFile('archive (1).zip') as zip_ref:
#       3     zip_ref.extractall('datasets')
#
# File C:\ProgramData\anaconda3\Lib\zipfile\__init__.py:1385, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1383 try:
#    1384     if mode == 'r':
# -> 1385         self._RealGetContents()
#    1386     elif mode in ('w', 'x'):
#    1387         # set the modified flag so central directory gets written
#    1388         # even if no files are added to the archive
#    1389         self._didModify = True
#
# File C:\ProgramData\anaconda3\Lib\zipfile\__init__.py:1452, in ZipFile._RealGetContents(self)
#    1450     raise BadZipFile("File is not a zip file")
#    1451 if not endrec:
# ...
